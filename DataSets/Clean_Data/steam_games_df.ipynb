# %%
import pandas as pd
import csv
import psycopg2

# %%
# create a reference to the csv and import into pandas dataframe
csv_path = (r"C:\\Users\\abrow\\Desktop\\EMERSON_BOOTCAMP\\BOOTCAMP_AMB\\Project 2\\Project-2-ETL\\DataSets\steam.csv")
steam_games_df = pd.read_csv(csv_path)

# %%
steam_games_df.head()
# Out:
#    appid                       name release_date  english         developer  \
# 0     10             Counter-Strike    11/1/2000        1             Valve
# 1     20      Team Fortress Classic     4/1/1999        1             Valve
# 2     30              Day of Defeat     5/1/2003        1             Valve
# 3     40         Deathmatch Classic     6/1/2001        1             Valve
# 4     50  Half-Life: Opposing Force    11/1/1999        1  Gearbox Software
#
#   publisher          platforms  required_age  \
# 0     Valve  windows;mac;linux             0
# 1     Valve  windows;mac;linux             0
# 2     Valve  windows;mac;linux             0
# 3     Valve  windows;mac;linux             0
# 4     Valve  windows;mac;linux             0
#
#                                           categories  genres  \
# 0  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 1  Multi-player;Online Multi-Player;Local Multi-P...  Action
# ...

# %%
#getting the data types for each column
steam_games_df.dtypes
# Out:
# appid                 int64
# name                 object
# release_date         object
# english               int64
# developer            object
# publisher            object
# platforms            object
# required_age          int64
# categories           object
# genres               object
# steamspy_tags        object
# achievements          int64
# positive_ratings      int64
# negative_ratings      int64
# average_playtime      int64
# median_playtime       int64
# owners               object
# price               float64
# dtype: object

# %%
#converting release_date to datetime from object
steam_games_df['release_date']=pd.to_datetime(steam_games_df['release_date'], format='%m-%d-%Y')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     455             try:
# --> 456                 values, tz = conversion.datetime_to_datetime64(arg)
#     457                 dta = DatetimeArray(values, dtype=tz_to_dtype(tz))
#
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-d0612aaeaa06> in <module>
#       1 #converting release_date to datetime from object
# ...

# %%
#Export file as csv
clean_steam_games_df.to_csv("Output/clean_steam_games_df.csv", index=False, header=True)
